# %% [markdown]
# ## Purpose
#
# This notebook is used to compare predictions of different models to determine the best ones

# %%
# Import our dependencies.
from pathlib import Path
import pandas as pd
from matplotlib import pyplot as plt

# %%
# Pull the prediciton dataframes in for comparison
pred_df1 = pd.read_csv(Path("../../Data/model_predictions/mse_loss_model1_pred_vs_true.csv"))
pred_df2 = pd.read_csv(Path("../../Data/model_predictions/mae_loss_model_1_pred_vs_true.csv"))
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /var/folders/d1/f_9n6s0d4n18whr4jcynx9zm0000gq/T/ipykernel_73570/3884796522.py in <module>
#       1 # Pull the prediciton dataframes in for comparison
#       2 pred_df1 = pd.read_csv(Path("../../Data/model_predictions/mse_loss_model1_pred_vs_true.csv"))
# ----> 3 pred_df2 = pd.read_csv(Path("../../Data/model_predictions/rev_model_1_pred_vs_true.csv"))
#
# ~/opt/anaconda3/envs/mlenv/lib/python3.7/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ...

# %%
pred_cols = ['assault_count_true_value', 'assault_count_pred_value',
       'assault_count_pred_delta', 'auto_theft_count_true_value',
       'auto_theft_count_pred_value', 'auto_theft_count_pred_delta',
       'bicycle_theft_count_true_value', 'bicycle_theft_count_pred_value',
       'bicycle_theft_count_pred_delta', 'break_and_enter_count_true_value',
       'break_and_enter_count_pred_value', 'break_and_enter_count_pred_delta',
       'robbery_count_true_value', 'robbery_count_pred_value',
       'robbery_count_pred_delta', 'theft_from_motor_vehicle_count_true_value',
       'theft_from_motor_vehicle_count_pred_value',
       'theft_from_motor_vehicle_count_pred_delta']

# %%
pred_df1 = pred_df1[pred_cols]
pred_df2 = pred_df2[pred_cols]

# %%
pred_df1.describe()
# Out:
#        assault_count_true_value  assault_count_pred_value  \
# count                366.000000                366.000000
# mean                  43.199454                 43.434426
# std                   10.197023                  7.355163
# min                   21.000000                 23.000000
# 25%                   37.000000                 39.000000
# 50%                   43.000000                 43.000000
# 75%                   48.750000                 48.000000
# max                  133.000000                 65.000000
#
#        assault_count_pred_delta  auto_theft_count_true_value  \
# count                366.000000                   366.000000
# mean                  -0.234973                     9.489071
# std                   10.634886                     3.639003
# min                  -26.000000                     2.000000
# 25%                   -6.000000                     7.000000
# 50%                   -1.000000                     9.000000
# ...

# %%
pred_df2.describe()
# Out:
#        assault_count_true_value  assault_count_pred_value  \
# count                366.000000                366.000000
# mean                  43.199454                 43.975410
# std                   10.197023                  6.101601
# min                   21.000000                 25.000000
# 25%                   37.000000                 40.000000
# 50%                   43.000000                 44.000000
# 75%                   48.750000                 48.000000
# max                  133.000000                 60.000000
#
#        assault_count_pred_delta  auto_theft_count_true_value  \
# count                366.000000                   366.000000
# mean                  -0.775956                     9.489071
# std                   10.414114                     3.639003
# min                  -27.000000                     2.000000
# 25%                   -7.000000                     7.000000
# 50%                   -2.000000                     9.000000
# ...

# %% [markdown]
# ## Distribution of Pred vs True Deltas

# %% [markdown]
# ### Assault

# %%
col_name = 'assault_count_pred_delta'
plt.hist(pred_df1[col_name], bins=30)
plt.xlabel(col_name)
plt.ylabel('Frequency')
plt.title('Distribution of ' + col_name + ' pred_df1')
plt.show()

# %%
col_name = 'assault_count_pred_delta'
plt.hist(pred_df2[col_name], bins=30)
plt.xlabel(col_name)
plt.ylabel('Frequency')
plt.title('Distribution of ' + col_name + ' pred_df2')
plt.show()

# %% [markdown]
# ### Auto Theft

# %%
col_name = 'auto_theft_count_pred_delta'
plt.hist(pred_df1[col_name], bins=20)
plt.xlabel(col_name)
plt.ylabel('Frequency')
plt.title('Distribution of ' + col_name + ' pred_df1')
plt.show()

# %%
col_name = 'auto_theft_count_pred_delta'
plt.hist(pred_df2[col_name], bins=20)
plt.xlabel(col_name)
plt.ylabel('Frequency')
plt.title('Distribution of ' + col_name + ' pred_df2')
plt.show()

# %% [markdown]
# ### Bicycle Theft

# %%
col_name = 'bicycle_theft_count_pred_delta'
plt.hist(pred_df1[col_name], bins=20)
plt.xlabel(col_name)
plt.ylabel('Frequency')
plt.title('Distribution of ' + col_name + ' pred_df1')
plt.show()

# %%
col_name = 'bicycle_theft_count_pred_delta'
plt.hist(pred_df2[col_name], bins=20)
plt.xlabel(col_name)
plt.ylabel('Frequency')
plt.title('Distribution of ' + col_name + ' pred_df2')
plt.show()

# %% [markdown]
# ### Breaking and Entering

# %%
col_name = 'break_and_enter_count_pred_delta'
plt.hist(pred_df1[col_name], bins=10)
plt.xlabel(col_name)
plt.ylabel('Frequency')
plt.title('Distribution of ' + col_name + ' pred_df1')
plt.show()

# %%
col_name = 'break_and_enter_count_pred_delta'
plt.hist(pred_df2[col_name], bins=10)
plt.xlabel(col_name)
plt.ylabel('Frequency')
plt.title('Distribution of ' + col_name + ' pred_df2')
plt.show()

# %% [markdown]
# ### Robbery

# %%
col_name = 'robbery_count_pred_delta'
plt.hist(pred_df1[col_name], bins=25)
plt.xlabel(col_name)
plt.ylabel('Frequency')
plt.title('Distribution of ' + col_name + ' pred_df1')
plt.show()

# %%
col_name = 'robbery_count_pred_delta'
plt.hist(pred_df2[col_name], bins=25)
plt.xlabel(col_name)
plt.ylabel('Frequency')
plt.title('Distribution of ' + col_name + ' pred_df2')
plt.show()

# %% [markdown]
# ### Theft From Motor Vehicle

# %%
col_name = 'theft_from_motor_vehicle_count_pred_delta'
plt.hist(pred_df1[col_name], bins=11)
plt.xlabel(col_name)
plt.ylabel('Frequency')
plt.title('Distribution of ' + col_name + ' pred_df1')
plt.show()

# %%
col_name = 'theft_from_motor_vehicle_count_pred_delta'
plt.hist(pred_df2[col_name], bins=11)
plt.xlabel(col_name)
plt.ylabel('Frequency')
plt.title('Distribution of ' + col_name + ' pred_df2')
plt.show()
