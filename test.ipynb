# %%
from project_tools.dataframe_tools import TorontoCrimeDataCleaner
from pathlib import Path

# %%
test = TorontoCrimeDataCleaner(2015, 2018)

# %%
test.list_all_dataframes()
# Out:
# There are no dataframes to display.

# %%
test.add_dataframe_from_csv("assault", Path("./datasets/Assault_Open_Data.csv"))

# %%
test.list_all_dataframes()
# Out:
# ------Active Dataframes------
# ['assault']

# %%
test.add_dataframe_from_csv("auto_theft", Path("./datasets/Auto_Theft_Open_Data.csv"))

# %%
test.add_dataframe_from_csv("bicycle_theft", Path("./datasets/Bicycle_Thefts_Open_Data.csv"))
# Out:
# Error in _drop_unneeded(): "['MCI_CATEGORY'] not in index"
# Error in _convert_column_types(): 'NoneType' object is not subscriptable
# Error in _filter_by_year(): 'NoneType' object is not subscriptable
# Error in _create_datetime_column(): 'NoneType' object is not subscriptable

# %%
test.merged_df()
# Out:
#        OCC_YEAR OCC_MONTH  OCC_DAY     OCC_DOW  OCC_HOUR PREMISES_TYPE  \
# 0          2015   January        1  Thursday          23         House
# 1          2015   January        1  Thursday           3    Commercial
# 2          2015   January        1  Thursday           2    Commercial
# 3          2015   January        1  Thursday           0    Commercial
# 4          2015   January        1  Thursday           0       Outside
# ...         ...       ...      ...         ...       ...           ...
# 91856      2017   January        1  Sunday            12       Outside
# 91857      2017   October        1  Sunday             0       Outside
# 91858      2015      June        1  Monday            12     Apartment
# 91859      2018      June       14  Thursday          11    Commercial
# 91860      2016   January        1  Friday             9       Outside
#
#       MCI_CATEGORY HOOD_140                       NEIGHBOURHOOD_140  \
# ...

# %%
test.df_dict['assault']
# Out:
#         OCC_YEAR  OCC_MONTH  OCC_DAY     OCC_DOW  OCC_HOUR PREMISES_TYPE  \
# 16824       2015    January        1  Thursday          23         House
# 16825       2015    January        1  Thursday           3    Commercial
# 16827       2015    January        1  Thursday           2    Commercial
# 16828       2015    January        1  Thursday           0    Commercial
# 16829       2015    January        1  Thursday           0       Outside
# ...          ...        ...      ...         ...       ...           ...
# 172776      2016       June        1  Wednesday          0       Outside
# 172867      2017        May       20  Saturday          10         House
# 172906      2018       June        1  Friday             0     Apartment
# 172952      2018  September        1  Saturday           0     Apartment
# 173090      2018   February        1  Thursday           0     Apartment
#
#        MCI_CATEGORY HOOD_140                       NEIGHBOURHOOD_140  \
# ...

# %%
test.df_dict['auto_theft']
# Out:
#        OCC_YEAR OCC_MONTH  OCC_DAY     OCC_DOW  OCC_HOUR PREMISES_TYPE  \
# 3635       2015   January        1  Thursday           6       Outside
# 3637       2015   January        1  Thursday           2       Outside
# 3640       2015   January        2  Friday            19       Outside
# 3641       2015   January        1  Thursday          16         House
# 3642       2015   January        2  Friday            18       Outside
# ...         ...       ...      ...         ...       ...           ...
# 29696      2017   January        1  Sunday            12       Outside
# 30090      2017   October        1  Sunday             0       Outside
# 31103      2015      June        1  Monday            12     Apartment
# 32082      2018      June       14  Thursday          11    Commercial
# 42194      2016   January        1  Friday             9       Outside
#
#       MCI_CATEGORY HOOD_140                         NEIGHBOURHOOD_140  \
# ...

# %%
test.export_all_cleaned()
# Out:
# Successfully saved Assault_Open_Data_cleaned_2015_2018.csv!
# Successfully saved Auto_Theft_Open_Data_cleaned_2015_2018.csv!
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /var/folders/d1/f_9n6s0d4n18whr4jcynx9zm0000gq/T/ipykernel_97986/2196282670.py in <module>
# ----> 1 test.export_all_cleaned()
#
# ~/Desktop/group_project/Weather_Impact_On_Crime_Rates/project_tools/dataframe_tools.py in export_all_cleaned(self, folder_name, file_prefix, file_suffix)
#     207             file_name = file_prefix + self.original_file_name[name] + file_suffix + "_" + str(self.min_year) + "_" + str(self.max_year) + ".csv"
#     208             file_save_path = os.path.join(folder_name, file_name)
# --> 209             dataframe.to_csv(file_save_path)
#     210
#     211             print(f'Successfully saved {file_name}!')
#
# AttributeError: 'NoneType' object has no attribute 'to_csv'
